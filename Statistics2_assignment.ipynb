# %% [markdown]
# Statistics Part2
# -

# %% [markdown]
# **1. What is hypothesis testing in statistics?**
# - Hypothesis testing is a statistical method used to make decisions about a population based on sample data.It is a process to determine whether the assumption we make about a population parameter is correct or not.
# - In hypothesis testing, we start by making two hypothesis:
# - **Null Hypothesis(H₀):** It represents the default assumption that there is no effect, no difference, or no relationship.
# - **Alternate Hypothesis(H₁ or Ha):** It represents what we want to prove that there is an effect, a difference or a relationship.
# - e.g.: Suppose a medicine claims to cure a disease in 80% of cases. We can perform hypothesis testing to check whether this claim is valid based on sample data from patients.Thus, hypothesis testing helps researchers and decision-makers conclude whether there is enough evidence in a sample to support a particular belief about a population.

# %% [markdown]
# **2. What is the null hypothesis, and how does it differ from the alternative hypothesis?**
# - In statistics, when we perform hypothesis testing, we make two competing statements about a population parameter: the null hypothesis and the alternative hypothesis.
#
# - **Null Hypothesis (H₀):**
# The null hypothesis is the default or initial assumption that there is no effect, no difference, or no relationship between variables. It represents the status quo or a statement of no change.
# We assume the null hypothesis is true until we find strong evidence against it.
#
# - **Alternative Hypothesis (H₁ or Ha):**
# The alternative hypothesis is what we want to prove. It suggests that there is an effect, a difference, or a relationship between variables. It is accepted if the evidence is strong enough to reject the null hypothesis.
#
# -**Example:**
# - H₀: A new drug has no effect on curing a disease.
# - H₁: A new drug does have an effect on curing a disease.
#
# In hypothesis testing, we either reject the null hypothesis or fail to reject it. We never "accept" the null hypothesis; we only say there is not enough evidence against it.

# %% [markdown]
# **3. What is the significance level in hypothesis testing, and why is it important?**
# - The significance level, often denoted by α (alpha), is a threshold used in hypothesis testing to decide whether to reject the null hypothesis.
# - It represents the probability of making a Type I error, which means rejecting the null hypothesis when it is actually true.
#
# - The significance level is usually set before conducting the test. Common values are:
#
# - 0.05 (5%)
#
# - 0.01 (1%)
#
# - 0.10 (10%)
#
# Interpretation:
# A significance level of 0.05 means that there is a 5% risk of concluding that a difference exists when there is no actual difference.
# - Example:
# If α = 0.05, and the p-value from the test is 0.03, then 0.03 < 0.05, so we reject the null hypothesis and conclude that the results are statistically significant.

# %% [markdown]
# **4. What does a P-value represent in hypothesis testing?**
# - In hypothesis testing, the P-value(probability value) represents the probability of observing the sample data or something more extreme, assuming that the null hypothesis  is true.
# - A low P-value (typically ≤ 0.05) suggests that the observed data is unlikely under the null hypothesis — so we reject the null hypothesis.
# - A high P-value (> 0.05) means the data is likely under the null hypothesis — so we fail to reject the null hypothesis.
# - example: A company claims that their battery lasts 10 hours on average. You're a researcher and suspect it lasts less than 10 hours, so you perform a hypothesis test.
#
# - Null Hypothesis (H₀): The battery lasts 10 hours (μ = 10).
#
# - Alternative Hypothesis (H₁): The battery lasts less than 10 hours (μ < 10).
#
# - You test 30 batteries and find the average life is 9.6 hours.
# After performing the statistical test, you get a P-value = 0.02.

# %% [markdown]
# **5. How do you interpret the P-value in hypothesis testing?**
# - The P-value helps you decide whether to reject or fail to reject the null hypothesis.
# - **P-value ≤ 0.05 → Statistically significant**
# → There is strong evidence against the null hypothesis
# → Reject the null hypothesis
#
# - **P-value > 0.05 → Not statistically significant**
# → There is weak evidence against the null hypothesis
# → Fail to reject the null hypothesis

# %% [markdown]
# **6. What are Type 1 and Type 2 errors in hypothesis testing?**
# - **Type 1 Error (False Positive):**
# - You reject the null hypothesis (H₀) when it is actually true.
#
# - It means you're seeing an effect that isn't really there.
#
# - Example: A COVID test says you're positive, but you're actually healthy.
#
# - Probability of Type 1 Error = α (alpha) → usually set at 0.05 (5%)
#
# - **Type 2 Error (False Negative):**
# - You fail to reject the null hypothesis (H₀) when it is actually false.It means you miss a real effect.
#
# - Example: A COVID test says you're negative, but you're actually infected.
#
# - Probability of Type 2 Error = β (beta)

# %% [markdown]
# **7. What is the difference between a one-tailed and a two-tailed test in hypothesis testing?**
# - **One-Tailed Test:**
# - Tests for an effect in one specific direction (either greater than or less than).
# - You use it when you expect the result to go only one way.
#
# - Example:
# A company claims a drug increases recovery rate.
#
# H₀: μ = 50
#
# H₁: μ > 50 (right-tailed)
#
# You're only interested if the value is greater than 50.
#
# - **Two-Tailed Test:**
# - Tests for an effect in both directions (either higher or lower).
# - You use it when you don’t know which direction the result might go.
#
# - Example:
# Testing if a new teaching method is different (could be better or worse).
#
# H₀: μ = 70
#
# H₁: μ ≠ 70
#
# You're interested if the value is not equal to 70 (could be < or >).

# %% [markdown]
# **8. What is the Z-test, and when is it used in hypothesis testing?**
# - A Z-test is a statistical test used to determine whether there is a significant difference between sample and population means (or between two samples), when the population standard deviation is known and the sample size is large (n ≥ 30).
# - **Z-test is used when:**
# 1. The sample size is large (n ≥ 30).
# 2. The population standard deviation (σ) is known.
# 3. The data is normally distributed (or approximately normal).
# - **Example:**
# - Suppose a battery company claims the average battery life is 100 hours (σ = 10).
# You test 50 batteries and find a sample mean of 96 hours.
# You use a Z-test to check if this difference is statistically significant.

# %% [markdown]
# **9. How do you calculate the Z-score, and what does it represent in hypothesis testing?**
# - **Z-score Formula:** Z= X - μ /(σ/✓n)
# - 𝑋 = sample mean
# - μ = population mean
# - σ = population standard deviation
# - n = sample size
# - The Z-score tells you how extreme your test statistic is under the assumption that the null hypothesis is true.
# - It helps you find the P-value, which you compare with the significance level (α) to decide whether to reject H₀.
# - Interpretation of Z-scores:
# Z = 0	Sample mean = population mean
# Z > 0	Sample mean is above population mean
# Z < 0	Sample mean is below population mean
# Z ≥ ±1.96	Statistically significant at α = 0.05 (two-tailed)
#
# **Example:**
# - 𝑋 = 96, 𝜇 = 100 , 𝜎 = 10, 𝑛 = 50
# - Z = 96 -100 / (10/✓50) = -4/1.41 = -2.84
# - Z = -2.84 means the sample mean is 2.84 standard deviations below the population mean.
# - If Z is very high or low (like ±2 or more), it usually means your result is statistically significant.

# %% [markdown]
# **10. What is the T-distribution, and when should it be used instead of the normal distribution?**
# - The T-distribution (or Student's t-distribution) is a bell-shaped probability distribution used in hypothesis testing when the sample size is small and the population standard deviation is unknown.It looks similar to the normal distribution but has fatter tails, which means it accounts for more variability in small samples.
# - Use the T-distribution when:
# 1. The sample size is small (n < 30)
# 2. The population standard deviation (σ) is unknown
# 3. The data is approximately normally distributed

# %% [markdown]
# **11. What is the difference between a Z-test and a T-test?**
# - The Z-test and T-test are both statistical methods used to determine whether there is a significant difference between means. They are often applied in hypothesis testing but are used in different scenarios based on sample size and the availability of population data.
# - **Z-test:**
# A Z-test is used when the population variance is known and the sample size is large (typically more than 30). It assumes that the data follows a normal distribution. The Z-test relies on the standard normal distribution (also known as the Z-distribution). It is commonly used to test hypotheses about population means or proportions.
# - **T-test:**
# A T-test is used when the population variance is unknown and the sample size is small (usually less than or equal to 30). It uses the t-distribution, which is similar to the normal distribution but has heavier tails. This accounts for the increased uncertainty in small samples. There are different types of T-tests, including the one-sample T-test, independent two-sample T-test, and paired sample T-test.

# %% [markdown]
# **12. What is the T-test, and how is it used in hypothesis testing?**
# - The T-test is a statistical method used to determine whether there is a significant difference between the means of two groups. It helps to evaluate if the observed data deviates significantly from what is expected under the null hypothesis. The T-test is especially useful when the sample size is small (n ≤ 30) and the population standard deviation is unknown.
# - **Types of T-tests:**
# **1. One-sample T-test:**
# Compares the mean of a single sample to a known value or population mean.
#
# **2. Independent two-sample T-test:**
# Compares the means of two independent groups to check if there is a significant difference between them.
#
# **3. Paired sample T-test:**
# Compares the means from the same group at two different times (before and after a treatment, for example).
# **Use in Hypothesis Testing:**
# 1. Set up hypotheses:
#
# - Null hypothesis (H₀): There is no significant difference between the means.
#
# - Alternative hypothesis (H₁): There is a significant difference.
#
# 2. Calculate the T-statistic using the formula.
#
# 3. Determine the degrees of freedom:
# Usually, df=n−1
#
# 4. Find the critical value or p-value using a T-distribution table.
#
# 5. Compare the T-statistic to the critical value:
#
# 6. If ∣t∣> critical value or p-value < significance level (α), reject the null hypothesis.Otherwise, fail to reject the null hypothesis

# %% [markdown]
# **13. What is the relationship between Z-test and T-test in hypothesis testing?**
# - **Relationship Between Z-test and T-test:**
# 1. Same Purpose in Hypothesis Testing:
# - Both tests help determine whether to reject or fail to reject the null hypothesis.
# - They compare a sample mean to a known population mean or compare means between two samples.
#
# 2. Based on the Same Logic:
#
# - Both tests use the difference between means, adjusted by the standard error, to compute a test statistic (Z or t).
#
# - Both follow a bell-shaped distribution (normal or t-distribution).
#
# 3. Depend on Sample Size and Known Parameters:
#
# - The Z-test is used when the population standard deviation is known and the sample size is large (n > 30).
#
# - The T-test is used when the population standard deviation is unknown and the sample size is small (n ≤ 30).
#
# 4. T-distribution Approaches Z-distribution:
#
# - As the sample size increases, the t-distribution becomes similar to the normal distribution.
# - For large samples, the T-test and Z-test give nearly the same results.

# %% [markdown]
# **14. What is a confidence interval, and how is it used to interpret statistical results?**
# - A confidence interval gives an estimated range of values which is likely to include the unknown population parameter. This range is calculated from the sample statistics and depends on the confidence level selected (commonly 90%, 95%, or 99%).
# - **Formula:** CI = X +- (Z or t) * s/✓n
# - Where:
# 1. X = sample mean
# 2. s = sample standard deviation
# 3. n = sample size
# 4. Z or 𝑡 = critical value depending on confidence level and sample size.
# - **Interpret a Confidence Interval:**
# If we construct a 95% confidence interval, it means that we are 95% confident that the true population mean lies within this interval. It does not mean there's a 95% chance that the population mean is in that interval — rather, if we repeated the sampling many times, 95% of the calculated intervals would contain the true mean.
# Example:
# - Suppose we calculate a 95% confidence interval for the average height of a group of students as:  - - [167.5 cm,172.5 cm]
# This means we are 95% confident that the true average height of all students lies between 167.5 cm and 172.5 cm.

# %% [markdown]
# **15. What is the margin of error, and how does it affect the confidence interval?**
# - The margin of error is the maximum expected difference between the true population value and a sample estimate, at a given confidence level. It depends on the critical value (Z or t), the standard deviation, and the sample size.
# - **Affects on the Confidence Interval:**
# The confidence interval (CI) is calculated as:
# CI = 𝑋 ± Margin of Error
#
# This means:
#
# - Wider MoE → Wider Confidence Interval
# (More uncertainty in the estimate)
#
# - Smaller MoE → Narrower Confidence Interval
# (More precise estimate)
#
# **Factors that affect the Margin of Error:**
# 1. Confidence level:
# Higher confidence (e.g., 99%) increases MoE.
# 2. Sample size (n):
# Larger samples reduce the MoE.
# 3. Data variability (standard deviation):
# More variability increases the MoE.
# **Example:**
# Suppose the average height from a sample is 170 cm, and the margin of error is 2 cm at a 95% confidence level.
#
# Then the confidence interval is:
# 170±2⇒(168,172)
# This means we are 95% confident that the true population mean height lies between 168 cm and 172 cm.

# %% [markdown]
# **16. How is Bayes' Theorem used in statistics, and what is its significance?**
# - Bayes' Theorem is a fundamental concept in statistics that describes how to update the probability of a hypothesis based on new evidence. It is used in a variety of fields such as medical testing, machine learning, risk analysis, and decision-making under uncertainty.
# - Bayes' Theorem calculates the posterior probability of an event based on prior knowledge and new data. The formula is:
# - P(A/B) = P(B/A). P(A)/ P(B)
# - P(A∣B): Posterior probability (probability of A given B is true)
# - P(B∣A): Likelihood (probability of B given A is true)
# - P(B): Total probability of B (all possible ways B can happen)
# **Use in Statistics:**
# 1. Updating beliefs:
# Bayes’ Theorem allows us to revise predictions or beliefs when new evidence is introduced.
#
# 2. Medical diagnosis:
# It helps calculate the probability of a disease given a positive test result, factoring in both test accuracy and the base rate of the disease.
#
# 3. Spam filtering:
# Used in email systems to update the probability that a message is spam based on the words it contains.
#
# 4. Machine learning (Bayesian models):
# Applied in models that continuously learn and improve predictions as more data becomes available.
#
# **Significance:**
# - Incorporates prior knowledge: Unlike classical statistics, it doesn’t ignore prior information.
#
# - Improves decision-making: Especially useful when evidence is incomplete or uncertain.
#
# - Foundation of Bayesian statistics: A growing area in data science and machine learning.

# %% [markdown]
# **17. What is the Chi-square distribution, and when is it used?**
# - The Chi-square distribution is a continuous probability distribution that is widely used in statistics, especially for hypothesis testing involving categorical data. It is right-skewed and takes only non-negative values (0 to ∞). The shape of the distribution depends on the degrees of freedom (df) — as the degrees of freedom increase, the distribution becomes more symmetrical.
# - The Chi-square distribution is defined as the distribution of a sum of the squares of independent standard normal variables. If Z1,Z2,...,Zk are independent standard normal variables, then:
# x^2 = z1^2+z2^2+...+zk^2
# This follows a Chi-square distribution with k degrees of freedom.
# **Uses:**
# 1. Chi-square Test for Independence:
# - Used to determine whether there is a relationship between two categorical variables in a contingency table.
# Example: Testing if gender and voting preference are related.
#
# 2. Chi-square Goodness-of-Fit Test:
# - Used to test whether a sample distribution matches an expected (theoretical) distribution.
# Example: Checking if a die is fair by comparing observed frequencies to expected frequencies.
#
# 3.Variance Tests:
# - Used to test the population variance of a normally distributed variable.

# %% [markdown]
# **18. What is the Chi-square goodness of fit test, and how is it applied?**
# - The Chi-square goodness of fit test is a statistical test used to determine whether a set of observed frequencies matches a corresponding set of expected frequencies for a categorical variable. It helps to assess whether a sample comes from a population with a specific distribution.
# - **Purpose:**
# To check if the observed data fits a theoretical distribution (e.g., uniform distribution, normal distribution, or any hypothesized pattern).
# - Steps to Apply the Chi-square Goodness of Fit Test:
# 1. State the Hypotheses:
#
# - Null Hypothesis: Observed data fits the expected distribution.
#
# - Alternative Hypothesis : Observed data does not fit the expected distribution.
#
# 2. Calculate Expected Frequencies:
#
# Use the theoretical distribution to compute Ei for each category.
#
# 3. Compute the Chi-square Statistic:
#
# - Plug values into the formula and calculate the χ2 value.
#
# 4. Determine Degrees of Freedom (df):
# - df=number of categories−1
# 5. Find the Critical Value or P-value:
# - Use a Chi-square distribution table to find the critical value at the chosen significance level (e.g., 0.05).
#
# 6. Make a Decision:
#
# - If χ2 > critical value → Reject 𝐻0
# - If χ2 ≤ critical value → Do not reject

# %% [markdown]
# **19. What is the F-distribution, and when is it used in hypothesis testing?**
# - The F-distribution is a continuous, right-skewed probability distribution that arises from the ratio of two independent chi-square variables divided by their degrees of freedom. It is always positive and depends on two degrees of freedom: one for the numerator and one for the denominator.
#
# In hypothesis testing, the F-distribution is mainly used in:
#
# **1. ANOVA (Analysis of Variance)**: To test whether the means of three or more groups are equal by comparing between-group and within-group variances.
#
# **2. Variance Comparison:** To test if two populations have equal variances.
#
# **3. Regression Analysis:** To test the overall significance of a regression model.

# %% [markdown]
# **20. What is an ANOVA test, and what are its assumptions?**
# - ANOVA (Analysis of Variance) is a statistical test used to determine whether there are significant differences between the means of three or more independent groups. Instead of comparing means one by one (which increases error), ANOVA compares overall group variance to detect any mean differences.
#
# Null Hypothesis (H0): All group means are equal.
#
# Alternative Hypothesis (H1): At least one group mean is different.
#
# **Assumptions of ANOVA:**
# **1. Independence:** Observations within and between groups must be independent.
#
# **2. Normality:** Data in each group should be approximately normally distributed.
#
# **3. Homogeneity of Variances:** All groups should have roughly equal variances (also called homoscedasticity).

# %% [markdown]
# **21. What are the different types of ANOVA tests?**
# - There are several types of ANOVA (Analysis of Variance) tests, each used based on the number of factors (independent variables) and how data is collected:
# 1. One-Way ANOVA
# Use: Compares the means of three or more groups based on one independent variable.
#
# Example: Comparing average marks of students from three different classes.
#
# 2. Two-Way ANOVA
# Use: Examines the effect of two independent variables on one dependent variable, and can also detect interaction effects.
#
# Example: Studying how both teaching method and gender affect test scores.
#
# 3. Repeated Measures ANOVA
# Use: Used when the same subjects are measured multiple times under different conditions or over time.
#
# Example: Measuring blood pressure of patients before, during, and after treatment.

# %% [markdown]
# **22. What is the F-test, and how does it relate to hypothesis testing?**
# - The F-test is a statistical method used to compare the variances of two or more groups to determine if they are significantly different from each other. It is based on the F-distribution, which is the ratio of two independent chi-square variables divided by their respective degrees of freedom. The F-test is commonly used in Analysis of Variance (ANOVA) and regression analysis.
# -The main purpose of the F-test is to evaluate whether the group means are significantly different by comparing the variability between the groups to the variability within the groups.
# - Formula: F = Variance bw groups / Variance within groups
# - A large F-value suggests a large difference between group means.
# - A small F-value suggests the group means are similar.
# - Relation to Hypothesis Testing:
# - The F-test is directly used in hypothesis testing with the following hypotheses:
#
#  Null Hypothesis (H₀): All group variances (or means, in the case of ANOVA) are equal.
#
#  Alternative Hypothesis (H₁): At least one group variance (or mean) is different.
#
# -If the calculated F-value is greater than the critical F-value from the F-distribution table, we reject the null hypothesis, indicating a statistically significant difference.

# %% [markdown]
# #Practical
# -

# %%
#1. Write a Python program to perform a Z-test for comparing a sample mean to a known population mean and interpret the results.
import numpy as np 
from scipy import stats 

sample_data = [72, 75, 78, 74, 77, 73, 76, 80, 79, 81] 
population_mean = 70 
population_std = 5 

sample_mean = np.mean(sample_data)
sample_size = len(sample_data)

z_score = (sample_mean - population_mean) / (population_std / np.sqrt(sample_size))
p_value = 1 - stats.norm.cdf(z_score) 

print(f"Sample Mean: {sample_mean:.2f}")
print(f"Z-score: {z_score:.2f}")
print(f"P-value: {p_value:.4f}")

alpha = 0.05
if p_value < alpha:
    print("Result: Reject the null hypothesis — the sample mean is significantly greater than the population mean.")
else:
    print("Result: Fail to reject the null hypothesis — no significant difference between sample and population mean.")
# Out:
# Sample Mean: 76.50
# Z-score: 4.11
# P-value: 0.0000
# Result: Reject the null hypothesis — the sample mean is significantly greater than the population mean.

# %%
#2. Simulate random data to perform hypothesis testing and calculate the corresponding P-value using Python.
import numpy as np 
from scipy import stats 

np.random.seed(42)
sample_data = np.random.normal(loc=85, scale=5, size=50)

population_mean = 80 
population_std = 10 

sample_mean = np.mean(sample_data) 
sample_size = len(sample_data)

z_score = (sample_mean - population_mean) / (population_std/ np.sqrt(sample_size))

p_value = 2 * (1 - stats.norm.cdf(abs(z_score))) 
print(f"Sample Mean: {sample_mean:.2f}")
print(f"Z-Score: {z_score:.4f}")
print(f"P-value: {p_value:.4f}")

alpha = 0.5 
if p_value < alpha: 
    print("Reject the null hypothesis: Sample mean is significantly different from population mean.")
else:
    print("Fail to reject the null hypothesis: No significant difference.")
# Out:
# Sample Mean: 83.87
# Z-Score: 2.7384
# P-value: 0.0062
# Reject the null hypothesis: Sample mean is significantly different from population mean.

# %%
#3. Implement a one-sample Z-test using Python to compare the sample mean with the population mean. 
import numpy as np 
from scipy.stats import norm 

sample_data = [101, 98, 99, 97, 102, 100, 99, 103, 100, 96] 

population_mean = 100 
population_std = 15 

sample_mean = np.mean(sample_data)
sample_size = len(sample_data)

z_score = (sample_mean - population_mean) / (population_std / np.sqrt(sample_size))

p_value = 2 * (1- norm.cdf(abs(z_score)))

print(f"Sample Mean: {sample_mean:.2f}")
print(f"Z-Score: {z_score:.4f}")
print(f"P-Value: {p_value:.4f}") 

alpha = 0.05
if p_value < alpha:
    print("Reject the null hypothesis: The sample mean is significantly different from the population mean.")
else:
    print("Fail to reject the null hypothesis: No significant difference between sample and population mean.")
# Out:
# Sample Mean: 99.50
# Z-Score: -0.1054
# P-Value: 0.9161
# Fail to reject the null hypothesis: No significant difference between sample and population mean.

# %%
#4. Perform a two-tailed Z-test using Python and visualize the decision region on a plot. 
import numpy as np 
import scipy.stats as stats 
import matplotlib.pyplot as plt 

mu = 100 
sigma = 15 
x_bar = 108
n = 36
alpha = 0.5 

standard_error = sigma / np.sqrt(n)
z = (x_bar - mu)/ standard_error
z_critical = stats.norm.ppf(1 - alpha/2)

print(f"Z-score: {z:.2f}")
print(f"Critical Z-value: ±{z_critical:.2f}") 

x = np.linspace(-4,4,1000)
y = stats.norm.pdf(x, 0, 1)

plt.figure(figsize=(10,5))
plt.plot(x,y, label='Standard Normal Distribution')

plt.fill_between(x, y, where=(x <= -z_critical) | (x >= z_critical), color = 'red', alpha = 0.3, label= 'Rejection Region')
plt.axvline(z, color='blue', linestyle = '--', label=f'Z = {z: .2f}')
plt.axvline(-z_critical, color='black', linestyle='--')
plt.axvline(z_critical, color='black', linestyle='--')

plt.title("Two-Tailed Z- Test: Rejection Regions")
plt.xlabel("Z-score")
plt.ylabel("Probability Density")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Z-score: 3.20
# Critical Z-value: ±0.67

# %%
#5. Create a Python function that calculates and visualizes Type 1 and Type 2 errors during hypothesis testing
import numpy as np 
import matplotlib.pyplot as plt 
import scipy.stats as stats 

def visualize_type1_type2_errors(mu0, mu1, sigma, n, alpha): 
    se = sigma / np.sqrt(n)

    z_critical = stats.norm.ppf(1 - alpha)
    x_critical = mu0 + z_critical * se 

    x = np.linspace(mu0 - 4*se, mu1 + 4*se, 1000)
    y_null = stats.norm.pdf(x, mu0, se) 
    y_alt = stats.norm.pdf(x, mu1, se)

    plt.figure(figsize=(12,6))
    plt.plot(x, y_null, label='Ho Distribution (μ = {})'.format(mu0), color='blue')
    plt.plot(x,y_alt, label= 'H1 Distribution (μ= {})'.format(mu1), color='green')
    plt.fill_between(x, y_null, where=(x > x_critical), color='red', alpha=0.3, label='Type 1 Error (α)')
    plt.fill_between(x, y_null, where=(x < x_critical), color='orange', alpha=0.3, label='Type 2 Error (β)') 

    plt.axvline(x_critical, color='black', linestyle= '--', label=f'Critical Value = {x_critical:.2f}')

    plt.title('Type I and Type II Errors in Hypothesis Testing')
    plt.xlabel('Sample Mean')
    plt.ylabel('Probability Density')
    plt.legend()
    plt.grid(True)
    plt.show()
visualize_type1_type2_errors(mu0=100, mu1=105, sigma=10, n=30, alpha=0.05)

# %%
#6. Write a Python program to perform an independent T-test and interpret the results. 
import numpy as np 
from scipy import stats 

group1 = [85, 90, 88, 75, 95, 79, 84]
group2 = [80, 78, 75, 70, 72, 68, 74] 

t_stat, p_value = stats.ttest_ind(group1, group2)

print(f"T-statistic: {t_stat:.3f}")
print(f"P-value: {p_value:.3f}")

alpha = 0.05

if p_value < alpha:
    print("Reject the null hypothesis: There is a significant difference between the two groups.")
else:
    print("Fail to reject the null hypothesis: No significant difference between the two groups.")
# Out:
# T-statistic: 3.753
# P-value: 0.003
# Reject the null hypothesis: There is a significant difference between the two groups.

# %%
#7. Perform a paired sample T-test using Python and visualize the comparison results. 
import numpy as np 
import matplotlib.pyplot as plt 
from scipy import stats 

before = [72, 75, 78, 70, 68, 74, 80, 76]
after  = [78, 78, 82, 74, 70, 75, 84, 80]

t_stat, p_value = stats.ttest_rel(before, after) 

print(f"T-statistic: {t_stat: .3f}")
print(f"P-value: {p_value:.3f}")

alpha = 0.05
if p_value < alpha:
    print("Reject H₀: There is a significant difference (before vs after).")
else:
    print("Fail to reject H₀: No significant difference (before vs after).")

x = np.arange(len(before))
width = 0.35

plt.figure(figsize=(10,5))
plt.bar(x - width/2, before, width, label='Before', color='skyblue')
plt.bar(x + width/2, after, width, label='After', color='orange')

plt.xlabel('Subjects')
plt.ylabel('Scores')
plt.title('Before vs After Comparison (Paired Sample')
plt.xticks(x) 
plt.legend()
plt.grid(True, axis='y', linestyle='--', alpha=0.5)  
plt.tight_layout()                                   
plt.show()
# Out:
# T-statistic: -6.548
# P-value: 0.000
# Reject H₀: There is a significant difference (before vs after).

# %%
#8. Simulate data and perform both Z-test and T-test, then compare the results using Python? 
import numpy as np 
import scipy.stats as stats 

np.random.seed(42)

population_mean = 100
sample = np.random.normal(loc=102, scale=10, size=50)

sample_mean = np.mean(sample)
sample_std = np.std(sample, ddof=1)
n = len(sample)

pop_std = 10 

z_score = (sample_mean - population_mean) / (pop_std / np.sqrt(n))
p_value_z = 2 * (1 - stats.norm.cdf(abs(z_score)))

t_stat, p_value_t = stats.ttest_1samp(sample, population_mean)

print(f"Z-test statistic: {z_score:.2f}")
print(f"Z-test p-value: {p_value_z:.4f}")

print(f"T-test statistic: {t_stat:.2f}")
print(f"T-test p-value: {p_value_t:.4f}")
# Out:
# Z-test statistic: -0.18
# Z-test p-value: 0.8571
# T-test statistic: -0.19
# T-test p-value: 0.8478

# %%
#9. Write a Python function to calculate the confidence interval for a sample mean and explain its significance? 
import numpy as np 
import scipy.stats as stats 

def confidence_interval(sample, confidence= 0.95): 
    n = len(sample)
    mean = np.mean(sample)
    std_err = stats.sem(sample)
    t_crit = stats.t.ppf((1 + confidence) / 2, df = n -1)
    margin = t_crit * std_err 
    lower = mean - margin 
    upper = mean + margin
    return round(lower, 2), round(upper, 2)

data = [52, 55, 53, 60, 58, 57, 54, 56, 59, 61]
ci = confidence_interval(data)
print("95% Confidence Interval:", ci)
# Out:
# 95% Confidence Interval: (54.33, 58.67)

# %%
#10. Write a Python program to calculate the margin of error for a given confidence level using sample data? 
import numpy as np 
import scipy.stats as stats 

def calculate_margin_of_error(sample, confidence=0.95): 
    n = len(sample) 
    std_err = stats.sem(sample)

    t_crit = stats.t.ppf((1+confidence) / 2, df = n - 1 )
    margin_error = t_crit * std_err 
    return round(margin_error, 2)

data = [52, 55, 53, 60, 58, 57, 54, 56, 59, 61]
moe = calculate_margin_of_error(data, confidence=0.95)
print("Margin of Error (95% confidence):", moe)
# Out:
# Margin of Error (95% confidence): 2.17

# %%
#11. Implement a Bayesian inference method using Bayes' Theorem in Python and explain the process. 
def bayes_theorem(prior_A, b_givenA, b_notgivenA): 
    prior_not_A = 1 - prior_A 
    numerator = b_givenA * prior_A 
    denominator = numerator + (b_notgivenA * prior_not_A)
    posterior = numerator / denominator 
    return round(posterior, 4)

P_Disease = 0.01                 
P_Pos_given_Disease = 0.99        
P_Pos_given_NoDisease = 0.05    

result = bayes_theorem(P_Disease, P_Pos_given_Disease, P_Pos_given_NoDisease)

print("P(Disease | Positive Test) =", result)
# Out:
# P(Disease | Positive Test) = 0.1667

# %%
#12.  Perform a Chi-square test for independence between two categorical variables in Python. 
import pandas as pd 
from scipy.stats import chi2_contingency 

data = [[20, 30], 
        [30, 20]]

chi2, p, dof, expected = chi2_contingency(data)

print("Chi-square Statistic:", chi2)
print("Degrees of Freedom:", dof)
print("P-value:", p)
print("Expected Frequencies:\n", expected)

alpha = 0.05  # significance level (5%)

if p < alpha:
    print("Reject the null hypothesis: Variables are dependent.")
else:
    print("Fail to reject the null hypothesis: Variables are independent.")
# Out:
# Chi-square Statistic: 3.24
# Degrees of Freedom: 1
# P-value: 0.07186063822585143
# Expected Frequencies:
#  [[25. 25.]
#  [25. 25.]]
# Fail to reject the null hypothesis: Variables are independent.

# %%
#13. Write a Python program to calculate the expected frequencies for a Chi-square test based on observed data.

import numpy as np 
from scipy.stats import chi2_contingency 

observed = np.array([
    [20,30],
    [30,20]
])

chi2, p, dof, expected = chi2_contingency(observed)

print("Observed Frequencies:")
print(observed)

print("\nExpected Frequencies (assuming independence):")
print(expected)

print("\nChi-square Statistic:", chi2)
print("Degrees of Freedom:", dof)
print("P-value:", p)
# Out:
# Observed Frequencies:
# [[20 30]
#  [30 20]]
#
# Expected Frequencies (assuming independence):
# [[25. 25.]
#  [25. 25.]]
#
# Chi-square Statistic: 3.24
# Degrees of Freedom: 1
# P-value: 0.07186063822585143

# %%
#14. Perform a goodness-of-fit test using Python to compare the observed data to an expected distribution. 

from scipy.stats import chisquare 

observed = [8, 9, 10, 11, 12, 10]

expected = [10, 10, 10, 10, 10, 10]

chi2_stat, p_value = chisquare(f_obs = observed, f_exp= expected)
print("Chi-square Statistic:", chi2_stat)
print("P-value:", p_value)

if p_value < 0.05:
    print("Reject the null hypothesis...")
# Out:
# Chi-square Statistic: 1.0
# P-value: 0.9625657732472964

# %%
#15. Create a Python script to simulate and visualize the Chi-square distribution and discuss its characteristics. 

import numpy as np 
import matplotlib.pyplot as plt 
from scipy.stats import chi2

x = np.linspace(0,20,500)
dfs = [1, 2, 5, 10]

plt.figure(figsize=(10,6))
for df in dfs: 
    plt.plot(x, chi2.pdf(x, df), label=f'df= {df}')

plt.title('Chi-square Distribution for Various Degrees of Freedom')
plt.xlabel('Chi-square value')
plt.ylabel('Probability Density')
plt.legend()
plt.grid(True)
plt.show()

# %%
#16. Implement an F-test using Python to compare the variances of two random samples. 
import numpy as np 
from scipy.stats import f 

np.random.seed(42)
sample1 = np.random.normal(loc=10, scale=2, size=30)
sample2 = np.random.normal(loc=10, scale=3, size=30)

var1 = np.var(sample1, ddof=1)
var2 = np.var(sample2, ddof=1)

if var1 > var2: 
    f_stat = var1 / var2 
    dfn = len(sample1) - 1
    dfd = len(sample2) - 1 
else:
    f_stat = var2 / var1
    dfn = len(sample2) - 1
    dfd = len(sample2) - 1

p_value = 2 * min(f.cdf(f_stat, dfn, dfd), 1 - f.cdf(f_stat, dfn, dfd))

alpha = 0.05
if p_value < alpha: 
    print("Reject the null hypothesis: Variances are significantly different.")
else: 
    print("Fail to reject the null hypothesis: Variances are not significantly different.")
# Out:
# Reject the null hypothesis: Variances are significantly different.

# %%
#17. Write a Python program to perform an ANOVA test to compare means between multiple groups and interpret the results. 
import numpy as np 
from scipy.stats import f_oneway 

group1 = np.random.normal(loc=50, scale=5, size=30)
group2 = np.random.normal(loc=52, scale=5, size=30)
group3 = np.random.normal(loc=60, scale=5, size=30)

f_stat, p_value = f_oneway(group1, group2, group3)
print("F-statistic:", f_stat)
print("p-value:", p_value)

alpha = 0.05
if p_value < alpha:
    print("Reject the null hypothesis: At least one group mean is significantly different.")
else: 
    print("Fail to reject the null hypothesis: No significant difference between group means.")
# Out:
# F-statistic: 31.697774111583964
# p-value: 4.564212013042183e-11
# Reject the null hypothesis: At least one group mean is significantly different.

# %%
#18. Perform a one-way ANOVA test using Python to compare the means of different groups and plot the result. 
import numpy as np 
import matplotlib.pyplot as plt 
from scipy.stats import f_oneway

group1 = np.random.normal(loc=50, scale=5, size=30)
group2 = np.random.normal(loc=52, scale=5, size=30)
group3 = np.random.normal(loc=60, scale=5, size=30)

f_stat, p_value = f_oneway(group1, group2, group3)
print("F-statistic:", f_stat)
print("p-value:", p_value)

alpha = 0.05
if p_value < alpha:
    print("Reject the null hypothesis: At least one group mean is significantly different")
else:
    print("Fail to reject null hypothesis: No significant difference between group means")

plt.boxplot([group1, group2, group3], tick_labels = ['Group 1', 'Group 2', 'Group 3'])
plt.title('Boxplot of Groups')
plt.ylabel('Values')
plt.grid(True)
plt.show()
# Out:
# F-statistic: 50.815178316676956
# p-value: 2.3987418089562057e-15
# Reject the null hypothesis: At least one group mean is significantly different

# %%
#19. Write a Python function to check the assumptions (normality, independence, and equal variance) for ANOVA. 
import numpy as np 
import scipy.stats as stats 
import matplotlib.pyplot as plt 
import seaborn as sns 

def check_anova_assumptions(*groups):
    all_data = np.concatenate(groups)
    labels = []
    for i, group in enumerate(groups): 
        labels += [f'Group {i+1}'] * len(group)
    print("=== Checking Normality (Shapiro-Wilk Test) ===")
    for i, group in enumerate(groups): 
        stat, p = stats.shapiro(group)
        print(f"Group {i+1}: W={stat:.4f}, p-value={p:.4f}")
    print("Checking Equal Variance")
    stat, p = stats.levene(*groups)
    print(f"Levene's Test: W= {stat:.4f}, p-value={p:.4f}")

    print("\n=== Checking Independence ===")
    print("ℹ️ Independence is assumed based on proper experimental design (e.g., random sampling). Cannot be tested directly from data.")

    plt.figure(figsize=(10,5))
    sns.boxplot(x=labels, y=all_data)
    plt.title("Boxplot of Groups (Visual check for spread)")
    plt.ylabel("Values")
    plt.grid(True) 
    plt.show()

    plt.figure(figsize=(10,5))
    for i, group in enumerate(groups):
        sns.kdeplot(group, label=f'Group {i+1}')
    plt.title("KDE Plot for Visual Normality check")
    plt.xlabel("Value")
    plt.legend()
    plt.grid(True)
    plt.show()

group1 = np.random.normal(loc=50, scale=5, size=30)  
group2 = np.random.normal(loc=52, scale=5, size=30)  
group3 = np.random.normal(loc=60, scale=5, size=30) 

check_anova_assumptions(group1,group2,group3)
# Out:
# === Checking Normality (Shapiro-Wilk Test) ===
# Group 1: W=0.9659, p-value=0.4337
# Group 2: W=0.9750, p-value=0.6815
# Group 3: W=0.9270, p-value=0.0409
# Checking Equal Variance
# Levene's Test: W= 0.6325, p-value=0.5337
#
# === Checking Independence ===
# ℹ️ Independence is assumed based on proper experimental design (e.g., random sampling). Cannot be tested directly from data.

# %%
#20. Perform a two-way ANOVA test using Python to study the interaction between two factors and visualize the results?
import pandas as pd 
import numpy as np 

np.random.seed(1)

fertilizer = ['A','B','C']
watering = ['Daily','Weekly']
data = []

for f in fertilizer: 
    for w in watering: 
        for _ in range(10): 
            growth = np.random.normal(loc=20 + 5 * fertilizer.index(f) - 2 * watering.index(w), scale=2)
            data.append([f,w,growth])
df = pd.DataFrame(data, columns=['Fertilizer','Watering','Growth'])

import statsmodels.api as sm 
from statsmodels.formula.api import ols 

model = ols("Growth ~ C(Fertilizer) * C(Watering)", data=df).fit()
annova_table = sm.stats.anova_lm(model, typ = 2)
print(annova_table)

import seaborn as sns 
import matplotlib.pyplot as plt 

sns.pointplot(data = df, x='Fertilizer', y='Growth', hue="Watering", dodge=True, markers=['o', 's'], capsize=.1, err_kws={'linewidth':1}, palette= 'colorblind')
plt.title("Interaction Plot: Fertilizer vs Watering on Growth")
plt.ylabel("Mean Plant Growth")
plt.grid(True)
plt.show()
# Out:
#                                 sum_sq    df           F        PR(>F)
# C(Fertilizer)              1139.909593   2.0  154.261575  4.705073e-23
# C(Watering)                  76.672437   1.0   20.751840  3.023781e-05
# C(Fertilizer):C(Watering)     0.550855   2.0    0.074546  9.282601e-01
# Residual                    199.515394  54.0         NaN           NaN

# %%
#21  Write a Python program to visualize the F-distribution and discuss its use in hypothesis testing? 
import numpy as np 
import matplotlib.pyplot as plt 
from scipy.stats import f 

dfn = 5
dfd = 20 

x = np.linspace(0,5,500)
y = f.pdf(x, dfn, dfd)

plt.figure(figsize=(8,5))
plt.plot(x,y, label=f'F-distribution\n(dfn={dfn}, dfd={dfd})', color='darkblue')
plt.title('F-Distribution')
plt.xlabel('F-value')
plt.ylabel('Probability Density')
plt.grid(True)
plt.legend()

alpha = .05 
f_critical = f.ppf(1 - alpha, dfn, dfd)
plt.axvline(f_critical, color='red', linestyle='--', label=f'Critical Value = {f_critical:.2f}')
plt.fill_between(x, y, where=(x >= f_critical), color='red', alpha=0.3, label='Rejection Region')
plt.legend()
plt.show()

# Use of F-Distribution in Hypothesis Testing 
#1. A right skewed Distribution used to compare two variances. 
#2.Commonly used in: 
# One way ANOVA, Two way ANOVA, Regression analysis

# %%
#22. Perform a one-way ANOVA test in Python and visualize the results with boxplots to compare group means? 
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns
from scipy.stats import f_oneway 

np.random.seed(0)
group_A = np.random.normal(loc=20, scale=3, size=30)
group_B = np.random.normal(loc=24, scale=3, size=30)
group_C = np.random.normal(loc=26, scale=3, size=30)

data = pd.DataFrame({
    'Score': np.concatenate([group_A, group_B, group_C]),
    'Group': ['A']*30 + ['B']*30 + ['C']*30 
})

f_stat, p_value = f_oneway(group_A, group_B, group_C)

print(f"F-statistic: {f_stat:.2f}")
print(f"P-Value: {p_value:.4f}")

plt.figure(figsize=(8,5))
sns.boxplot(data=data, x='Group', y='Score', palette='pastel')
plt.title('Group Comparision using One-Way ANOVA')
plt.ylabel('Score')
plt.grid(True)
plt.show()
# Out:
# F-statistic: 15.43
# P-Value: 0.0000
# C:\Users\aashu\AppData\Local\Temp\ipykernel_16148\275534861.py:24: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=data, x='Group', y='Score', palette='pastel')

# %%
#23. Simulate random data from a normal distribution, then perform hypothesis testing to evaluate the means? 
import numpy as np 
import scipy.stats as stats 
import matplotlib.pyplot as plt 
import seaborn as sns 

np.random.seed(0)

group_A = np.random.normal(loc=50, scale=5, size=100)
group_B = np.random.normal(loc=52, scale=5, size=100)

t_stat, p_value = stats.ttest_ind(group_A, group_B)

print(f"T-Statistic: {t_stat:.2f}")
print(f"P-value: {p_value:.4f}")

alpha = 0.05 
if p_value < alpha:
    print("Reject the null hypothesis")
else:
    print("Fail to reject the null hypothesis")

plt.figure(figsize=(10,5))
sns.histplot(group_A, kde=True, color="blue", label="Group A", bins=20)
sns.histplot(group_B, kde=True, color="orange", label="Group B", bins =20)
plt.title("Distribution of Group A and B")
plt.xlabel("Value")
plt.ylabel("frequency")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# T-Statistic: -2.91
# P-value: 0.0040
# Reject the null hypothesis

# %%
#24. Perform a hypothesis test for population variance using a Chi-square distribution and interpret the results.
import numpy as np 
from scipy.stats import chi2 

np.random.seed(42)
sample = np.random.normal(loc=50, scale=8, size=30)

sigma_0_squared = 64
n = len(sample)

sample_variance = np.var(sample, ddof=1)

chi_square_stat = (n-1) * sample_variance / sigma_0_squared
alpha = 0.05
df = n-1

chi2_lower = chi2.ppf(alpha / 2, df)
chi2_upper = chi2.ppf(1-alpha /2, df)

print(f"Sample Variance: {sample_variance:.2f}")
print(f"Chi-square Statistic: {chi_square_stat:.2f}")
print(f"Chi-square Critical Values: [{chi2_lower:.2f}, {chi2_upper:.2f}]")

if chi_square_stat < chi2_lower or chi_square_stat > chi2_upper:
    print("Reject the null hypothesis: The population variance is significantly different.")
else:
    print("Fail to reject the null hypothesis: No significant difference in population variance.")
# Out:
# Sample Variance: 51.84
# Chi-square Statistic: 23.49
# Chi-square Critical Values: [16.05, 45.72]
# Fail to reject the null hypothesis: No significant difference in population variance.

# %%
#25 Write a Python script to perform a Z-test for comparing proportions between two datasets or groups.
from statsmodels.stats.proportion import proportions_ztest


successes = [56, 60]
nobs = [80, 90]

z_stat, p_value = proportions_ztest(count=successes, nobs=nobs)

print(f"Z-statistic: {z_stat:.2f}")
print(f"P-value: {p_value:.4f}")

alpha = 0.05
if p_value < alpha:
    print("Reject the null hypothesis: The proportions are significantly different.")
else:
    print("Fail to reject the null hypothesis: No significant difference in proportions.")
# Out:
# Z-statistic: 0.47
# P-value: 0.6412
# Fail to reject the null hypothesis: No significant difference in proportions.

# %%
#26. Implement an F-test for comparing the variances of two datasets, then interpret and visualize the results. 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns 

np.random.seed(42)
group1 = np.random.normal(loc=50, scale=10, size=100)
group2 = np.random.normal(loc=52, scale=15, size=100)

var1 = np.var(group1, ddof=1)
var2 = np.var(group2, ddof=1)

F = var1 / var2 if var1 > var2 else var2 / var1 
df1 = len(group1) - 1 
df2 = len(group2) - 1 

from scipy.stats import f 
p_value = 2 *(1- f.cdf(F, df1, df2)) if var1 >var2 else 2 * f.cdf(F, df1, df2)

print(f"Sample Variance 1: {var1:.2f}")
print(f"Sample Variance 2: {var2:.2f}")
print(f"F-statistic: {F:.2f}")
print(f"P-value: {p_value:.4f}")

alpha = 0.05
if p_value < alpha:
    print("Reject the null hypothesis: Variances are significantly different.")
else:
    print("Fail to reject the null hypothesis: No significant difference in variances.")

plt.figure(figsize=(10, 5))
sns.kdeplot(group1, label='Group 1', fill=True)
sns.kdeplot(group2, label='Group 2', fill=True)
plt.title("Distribution of Group 1 and Group 2")
plt.xlabel("Values")
plt.ylabel("Density")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Sample Variance 1: 82.48
# Sample Variance 2: 204.63
# F-statistic: 2.48
# P-value: 2.0000
# Fail to reject the null hypothesis: No significant difference in variances.

# %%
#27. Perform a Chi-square test for goodness of fit with simulated data and analyze the results. 
import numpy as np
from scipy.stats import chisquare
import matplotlib.pyplot as plt

# Step 1: Simulate observed data
observed = np.array([18, 22, 19, 17, 25, 19])  # Simulated die rolls

# Step 2: Define expected data
expected = np.array([20] * 6)  # Equal probability for 6 faces (uniform)

# Step 3: Perform Chi-square goodness of fit test
chi_stat, p_value = chisquare(f_obs=observed, f_exp=expected)

# Step 4: Print results
print(f"Chi-square Statistic: {chi_stat:.2f}")
print(f"P-value: {p_value:.4f}")

# Step 5: Interpret the result
alpha = 0.05
if p_value < alpha:
    print("Reject the null hypothesis: Observed frequencies do NOT match expected.")
else:
    print("Fail to reject the null hypothesis: Observed frequencies match expected.")

# Step 6: Visualization
labels = ['1', '2', '3', '4', '5', '6']
x = np.arange(len(labels))
width = 0.35

plt.bar(x - width/2, observed, width=width, label='Observed')
plt.bar(x + width/2, expected, width=width, label='Expected')
plt.xlabel('Die Face')
plt.ylabel('Count')
plt.title('Observed vs Expected Frequencies')
plt.xticks(x, labels)
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Chi-square Statistic: 2.20
# P-value: 0.8208
# Fail to reject the null hypothesis: Observed frequencies match expected.
